# %% [markdown]
# <a href="https://colab.research.google.com/github/AkaMajed/MY-ALP-/blob/main/DAY1_IN_ALP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **programming**
# *Chat bot*

# %%
name = input("what's your name?")
print("Hi! " +  name)
name6 = input(" who are you ?")
name3 = input(" how are you ?")
name4 = input(" where are you ?")
print( name6 + " Nice")
print( name3 + " so you are good")
print( name4 + " a far place")
# Out:
# what's your name?aa
# Hi! aa
#  who are you ?sdf
#  how are you ?adf
#  where are you ?adf
# sdf Nice
# adf so you are good
# adf a far place

# %% [markdown]
# #TASK 1
# # numbers

# %%
print(9 + 12)
print(9 - 2)
print( 12572 * 232124)
print(1258993 / 215125)
print( 1258993 // 215125)
# Out:
# 21
# 7
# 2918262928
# 5.852378849506101
# 5

# %%
score = 0
print(score)
score = score + 1
print(score)
# Out:
# 0
# 1

# %%
num1 = int(input("enter a number"))
# Out:
# enter a number23

# %% [markdown]
# #TASK 5

# %%
name = str(input("Hi user ! how are you ? im gonna help you with doing your cals so put the length here?"))
print("Hi so this is the length  " + name)
name2 = str(input("Hi user ! how are you ? im gonna help you with doing your cals so put the width here?"))
print("Hi so this is the width  " + name2)
name = int(name)
name2 = int(name2)
print( name * name2 )
# Out:
# Hi user ! how are you ? im gonna help you with doing your cals so put the length here?2
# Hi so this is the length  2
# Hi user ! how are you ? im gonna help you with doing your cals so put the width here?2
# Hi so this is the width  2
# 4

# %% [markdown]
# #TASK 6

# %%
name = str(input("Hi user ! how are you ? im gonna help you with doing your cals so put the length here?"))
print("Hi so this is the length  " + name)
name2 = str(input("Hi user ! how are you ? im gonna help you with doing your cals so put the width here?"))
print("Hi so this is the width  " + name2)
name = int(name)
name2 = int(name2)
print( name * 2 + name2 * 2 )
# Out:
# Hi user ! how are you ? im gonna help you with doing your cals so put the length here?2
# Hi so this is the length  2
# Hi user ! how are you ? im gonna help you with doing your cals so put the width here?2
# Hi so this is the width  2
# 8

# %% [markdown]
# #I DID IT IN CLASS BUT AT THE END I MESSED IT

# %%
amount = int(input("Hi user ! how are you ? im gonna help you with doing your cals so put the bill amount here?"))
print("Hi so this is the bill  ", amount)
tippr = int(input("Hi user ! how are you ? im gonna help you with doing your cals so put the tip percent here?"))
print("Hi so this is the tip percent  " , name2)
name = int(name)
name2 = int(name2)
print( tippr * amount / 100)
# Out:
# Hi user ! how are you ? im gonna help you with doing your cals so put the bill amount here?10
# Hi so this is the bill   10
# Hi user ! how are you ? im gonna help you with doing your cals so put the tip percent here?2
# Hi so this is the tip percent   2
# 0.2

# %%
name = str(input("Hi user ! how are you ? im gonna help you with doing your cals so put the length here?"))
print("Hi so this is the length  " + name)
name2 = str(input("Hi user ! how are you ? im gonna help you with doing your cals so put the width here?"))
print("Hi so this is the width  " + name2)
name3 = str(input("Hi user ! how are you ? im gonna help you with doing your cals so put the height here?"))
print("Hi so this is the height  " + name3)

name = int(name)
name2 = int(name2)
name3 = int(name3)

print( name * name2 * name3)

# %% [markdown]
# #BOALLEN

# %%
num1 = 100
num2 = 50
if num1 > num2:
  print("num1 is bigger")

print("end of program")
# Out:
# num1 is bigger
# end of program

# %% [markdown]
# #TASKS PART 2

# %%
pasd = 1337
password2= input("hi user can you guess the password ?")
if pasd==password2:
  print("correct")
else:
  print("incorrect")
# Out:
# hi user can you guess the password ?1337
# incorrect

# %%
firstone= input("what subject are you studying?")
secondone= input("whats your name ?")
if firstone=="computerscince":
  print("Hi!" + secondone + " go to room 401")
elif firstone=="economics":
  print("Hi!" + secondone + " go to room 411")
elif firstone=="humanbody":
  print("Hi!" + secondone  + " go to room 421")
else:
  print("i'm sorry i don't know the room")
# Out:
# what subject are you studying?hi
# whats your name ?hi
# i'm sorry i don't know the room

# %%
thename = input("What's your lovely Name? ")
thenumbers = int(input("Can you choose a number between one to five please? "))
if thenumbers == 1:
    print(thename + ", shut up")
elif thenumbers == 2:
    print(thename + ", don't shut up")
elif thenumbers == 3:
    print(thename + ", stupid face")
elif thenumbers == 4:
    print(thename + ", shush")
elif thenumbers == 5:
    print(thename + ", don't shush")
else:
    print("Please choose a number between 1 and 5")
# Out:
# What's your lovely Name? majed
# Can you choose a number between one to five please? 2
# majed, don't shut up

# %%
counter = 1
while counter < 5:
  print("hello")
# Out:
# Streaming output truncated to the last 5000 lines.
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
secretnumber = 7
omg = int(input("Guess a number:"))
while omg != secretnumber:
  omg= int(input("Guess again:"))
print("Good job!!!")
# Out:
# Guess a number:7
# Good job!!!

# %%
numberr= 80
while numberr <= 84:
  print("one second")
  numberr +=1
  print("thats it 84")
# Out:
# one second
# thats it 84
# one second
# thats it 84
# one second
# thats it 84
# one second
# thats it 84
# one second
# thats it 84

# %% [markdown]
# HOME WORK CHALLENGE

# %%
cubes = int(input("Enter how much numbers you want: "))
n = 1

while n <= cubes:
    print(n**3)
    n += 1
# Out:
# Enter how much numbers you want: 3
# 1
# 8
# 27
